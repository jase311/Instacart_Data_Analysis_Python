# %% [markdown]
# # Exercise 4.6

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## Import the data set into Jupyter as a new dataframe: df_ords_prior

# %%
path = r'C:\Users\Jaime Andres Suarez\Instacart Basket Analysis'
df_ords_prior=pd.read_csv(os.path.join(path,'02 Data', 'Raw Data', 'orders_products_prior.csv'), index_col=False)
df_ords = pd.read_csv(os.path.join(path, '02 Data','Transformed Data', 'ords_clean.csv'))
df_prods = pd.read_csv(os.path.join(path, '02 Data','Transformed Data', 'prods_clean.csv'), index_col=False)
df_ords_prior
# Out:
#           order_id  product_id  add_to_cart_order  reordered
# 0                2       33120                  1          1
# 1                2       28985                  2          1
# 2                2        9327                  3          0
# 3                2       45918                  4          1
# 4                2       30035                  5          0
# ...            ...         ...                ...        ...
# 32434484   3421083       39678                  6          1
# 32434485   3421083       11352                  7          0
# 32434486   3421083        4600                  8          0
# 32434487   3421083       24852                  9          1
# 32434488   3421083        5020                 10          1
#
# [32434489 rows x 4 columns]

# %% [markdown]
# ## Check the dimensions of the imported dataframe

# %%
df_ords_prior.shape
# Out:
# (32434489, 4)

# %% [markdown]
# ## Merge the dataframe with your df_ords dataframe

# %%
df_ords
# Out:
#          order_id  user_id  order_number  orders_day_of_week  \
# 0         2539329        1             1                   2
# 1         2398795        1             2                   3
# 2          473747        1             3                   3
# 3         2254736        1             4                   4
# 4          431534        1             5                   4
# ...           ...      ...           ...                 ...
# 3421078   2266710   206209            10                   5
# 3421079   1854736   206209            11                   4
# 3421080    626363   206209            12                   1
# 3421081   2977660   206209            13                   1
# 3421082    272231   206209            14                   6
#
#          order_hour_of_day  days_since_prior_order
# 0                        8                     0.0
# 1                        7                    15.0
# 2                       12                    21.0
# ...

# %%
df_merged_large=df_ords.merge(df_ords_prior,on='order_id', indicator=True)
df_merged_large
# Out:
# NumExpr defaulting to 4 threads.
#           order_id  user_id  order_number  orders_day_of_week  \
# 0          2539329        1             1                   2
# 1          2539329        1             1                   2
# 2          2539329        1             1                   2
# 3          2539329        1             1                   2
# 4          2539329        1             1                   2
# ...            ...      ...           ...                 ...
# 32434484   2977660   206209            13                   1
# 32434485   2977660   206209            13                   1
# 32434486   2977660   206209            13                   1
# 32434487   2977660   206209            13                   1
# 32434488   2977660   206209            13                   1
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                     0.0         196
# ...

# %%
df_merged_large['_merge'].value_counts()
# Out:
# both          32434489
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %%
df_merged_large.drop(columns=df_merged_large.columns[-1],axis=1,inplace=True)

# %%
df_merged_large.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered
# 0                     0.0         196                  1          0
# 1                     0.0       14084                  2          0
# 2                     0.0       12427                  3          0
# 3                     0.0       26088                  4          0
# 4                     0.0       26405                  5          0

# %%
df_merged_large.to_csv(os.path.join(path, '02 Data','Transformed Data', 'orders_products_combined.csv'))

# %%
df_merged_large.to_pickle(os.path.join(path, '02 Data','Transformed Data', 'orders_products_combined.pkl'))

# %%
df_merged_large.shape
# Out:
# (32434489, 10)

# %%
df_merged_large.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3e109a95ebe8> in <module>
# ----> 1 df_merged_large.head()
#
# NameError: name 'df_merged_large' is not defined
