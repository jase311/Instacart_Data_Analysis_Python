# %% [markdown]
# # Exercise 4.8

# %% [markdown]
# ### Import Libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ### Load the file

# %%
path = r'C:\Users\Jaime Andres Suarez\Instacart Basket Analysis'
df=pd.read_pickle(os.path.join(path,'02 Data', 'Transformed Data', 'df_merged.pkl'))
df.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     0.0         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge    price_range_loc  \
# ...

# %% [markdown]
# ## Subset with a million records

# %%
df2=df[0:1000000]

# %%
df2.shape
# Out:
# (1000000, 17)

# %% [markdown]
# ## Grouping with Pandas

# %%
df2.groupby('product_name')

# %% [markdown]
# ## Aggregating Data with agg()

# %%
df2.groupby('department_id').agg({'order_number':['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 4                18.825780
# 7                17.472355
# 13               17.993423
# 14               19.246334
# 16               19.463012
# 17               11.294069
# 19               19.305237
# 20               17.599636

# %%
df2.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 4     18.825780
# 7     17.472355
# 13    17.993423
# 14    19.246334
# 16    19.463012
# 17    11.294069
# 19    19.305237
# 20    17.599636
# Name: order_number, dtype: float64

# %% [markdown]
# ## Performing Multiple Aggregations

# %%
df2.groupby('department_id').agg({'order_number':['mean','min','max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 4                18.825780   1  99
# 7                17.472355   1  99
# 13               17.993423   1  99
# 14               19.246334   1  99
# 16               19.463012   1  99
# 17               11.294069   1  98
# 19               19.305237   1  99
# 20               17.599636   1  99

# %% [markdown]
# ## Aggregating Data with transform()

# %% [markdown]
# ### 1. Split the data into groups based on the 'user_id" column

# %% [markdown]
# ### 2. Apply the transform() function on the “order_number” column to generate the maximum orders for each user

# %% [markdown]
# ### 3. Create a new column, “max_order,” into which you’ll place the results of your aggregation

# %%
df2['max_order']=df2.groupby(['user_id'])['order_number'].transform(np.max)
# Out:
# <ipython-input-12-1ddfe4930bb8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['max_order']=df2.groupby(['user_id'])['order_number'].transform(np.max)

# %%
pd.options.display.max_rows = None
df2.head(100)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2398795        1             2                   3                  7
# 2     473747        1             3                   3                 12
# 3    2254736        1             4                   4                  7
# 4     431534        1             5                   4                 15
# 5    3367565        1             6                   2                  7
# 6     550135        1             7                   1                  9
# 7    3108588        1             8                   1                 14
# 8    2295261        1             9                   1                 16
# 9    2550362        1            10                   4                  8
# 10   2968173       15            15                   1                  9
# ...

# %% [markdown]
# ## Deriving columns with loc()

# %%
df.loc[df['max_order']>40, 'loyalty_flag']='Loyal customer'
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'max_order'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-22ff5960cd80> in <module>
# ...

# %%
df.loc[(df['max_order']>10) & (df2['max_order']<=40), 'loyalty_flag']='Regular customer'
# Out:
# C:\Users\Jaime Andres Suarez\anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
df.loc[df['max_order']<=10, 'loyalty_flag']='New customer'
# Out:
# C:\Users\Jaime Andres Suarez\anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
df2['loyalty_flag'].value_counts(dropna=False)
# Out:
# Regular customer    463844
# Loyal customer      335086
# New customer        201070
# Name: loyalty_flag, dtype: int64

# %%
df2[['user_id','order_number','loyalty_flag']].head(30)
# Out:
#     user_id  order_number      loyalty_flag
# 0         1             1      New customer
# 1         1             2      New customer
# 2         1             3      New customer
# 3         1             4      New customer
# 4         1             5      New customer
# 5         1             6      New customer
# 6         1             7      New customer
# 7         1             8      New customer
# 8         1             9      New customer
# 9         1            10      New customer
# 10       15            15  Regular customer
# 11       15            17  Regular customer
# 12       15            18  Regular customer
# 13       15            21  Regular customer
# 14       15            22  Regular customer
# 15       19             2      New customer
# 16       19             5      New customer
# 17       19             7      New customer
# 18       21            10  Regular customer
# 19       31            10  Regular customer
# ...

# %% [markdown]
# ### Convert products with a price higher than 100 into NaN

# %%
df.loc[df['prices']>100,'prices']=np.nan
